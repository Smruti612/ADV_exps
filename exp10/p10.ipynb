# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("./datasets/dropout-ratio-2012-2015.csv")
df1
df2=pd.read_csv("./datasets/gross-enrollment-ratio-2013-2016.csv")
df3=pd.read_csv("./datasets/percentage-of-schools-with-comps-2013-2016.csv")
df4=pd.read_csv("./datasets/percentage-of-schools-with-electricity-2013-2016.csv")
df5=pd.read_csv("./datasets/percentage-of-schools-with-water-facility-2013-2016.csv")

# %%
df1
# Out:
#            State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0     A & N Islands  2012-13         0.83          0.51          0.68
# 1     A & N Islands  2013-14         1.35          1.06          1.21
# 2     A & N Islands  2014-15         0.47          0.55          0.51
# 3    Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4    Andhra Pradesh  2013-14         4.31          4.39          4.35
# ..              ...      ...          ...           ...           ...
# 105     West Bengal  2013-14         3.44          2.37          2.91
# 106     West Bengal  2014-15         2.13          0.79          1.47
# 107       All India  2012-13         4.68          4.66          4.67
# 108       All India  2013-14         4.53          4.14          4.34
# 109       All India  2014-15         4.36          3.88          4.13
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# ...

# %%
df1["Metric_Type"] = "Dropout"
df2["Metric_Type"] = "Gross Enrollment Ratio"
df3["Metric_Type"] = "Schools with Computers"
df4["Metric_Type"] = "Schools with Electricity"
df5["Metric_Type"] = "Schools with Water"

# %%
df2.sample(3)
# Out:
#              State_UT     Year  Primary_Boys  Primary_Girls  Primary_Total  \
# 78         Chandigarh  2014-15         83.62          91.49          87.11
# 75  Arunachal Pradesh  2014-15        128.78         127.45         128.13
# 20        Maharashtra  2013-14         99.93          99.68          99.81
#
#     Upper_Primary_Boys  Upper_Primary_Girls  Upper_Primary_Total  \
# 78               94.68               103.15                98.33
# 75              120.11               125.01               122.53
# 20               96.93                96.76                96.69
#
#     Secondary_Boys  Secondary_Girls  Secondary_Total Higher_Secondary_Boys  \
# 78           89.05            90.53            89.69                 90.05
# 75           93.11            90.10            91.62                    68
# 20           87.50            83.39            85.58                 58.87
#
#    Higher_Secondary_Girls Higher_Secondary_Total             Metric_Type
# ...

# %%
df3.sample(3)
# Out:
#          State_UT     year  Primary_Only  Primary_with_U_Primary  \
# 20   Chhattisgarh  2015-16          3.02                   43.42
# 99  Uttar Pradesh  2014-15          6.43                   27.71
# 26    Daman & Diu  2015-16         16.95                  100.00
#
#     Primary_with_U_Primary_Sec_HrSec  U_Primary_Only  \
# 20                              79.3           14.72
# 99                              55.9           16.64
# 26                             100.0           94.74
#
#     U_Primary_With_Sec_HrSec  Primary_with_U_Primary_Sec  U_Primary_With_Sec  \
# 20                     50.00                       65.37               20.86
# 99                     56.17                       36.18               25.27
# 26                    100.00                      100.00                0.00
#
#     Sec_Only  Sec_with_HrSec.  HrSec_Only  All Schools             Metric_Type
# 20     26.11            45.83        40.0        12.70  Schools with Computers
# ...

# %%
df4.sample(3)
# Out:
#                       State_UT     year  Primary_Only  Primary_with_U_Primary  \
# 107                  All India  2013-14         46.38                   69.56
# 2    Andaman & Nicobar Islands  2015-16         82.11                   97.62
# 13                       Bihar  2014-15         13.76                   36.32
#
#      Primary_with_U_Primary_Sec_HrSec  U_Primary_Only  \
# 107                             94.92           45.97
# 2                              100.00            0.00
# 13                              51.49           34.96
#
#      U_Primary_With_Sec_HrSec  Primary_with_U_Primary_Sec  U_Primary_With_Sec  \
# 107                     93.72                       83.12               86.84
# 2                      100.00                      100.00                0.00
# 13                      81.82                       37.29               33.07
#
#      Sec_Only  Sec_with_HrSec.  HrSec_Only  All Schools  \
# 107     75.08            82.88       91.01        56.78
# ...

# %%
df5.sample(3)
# Out:
#           State/UT     Year  Primary_Only  Primary_with_U_Primary  \
# 20    Chhattisgarh  2015-16         99.03                   98.91
# 89          Sikkim  2015-16         97.59                   99.42
# 100  Uttar Pradesh  2015-16         98.93                   99.86
#
#      Primary_with_U_Primary_Sec_HrSec  U_Primary_Only  \
# 20                              99.82           99.47
# 89                             100.00          100.00
# 100                             99.73           97.72
#
#      U_Primary_With_Sec_HrSec  Primary_with_U_Primary_Sec  U_Primary_With_Sec  \
# 20                     100.00                       99.81              100.00
# 89                     100.00                      100.00              100.00
# 100                     99.93                       99.90               99.86
#
#      Sec_Only  Sec_with_HrSec.  HrSec_Only  All Schools         Metric_Type
# 20      91.69            98.62      100.00        99.06  Schools with Water
# ...

# %%
df2.columns
# Out:
# Index(['State_UT', 'Year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper_Primary_Boys', 'Upper_Primary_Girls', 'Upper_Primary_Total',
#        'Secondary_Boys', 'Secondary_Girls', 'Secondary_Total',
#        'Higher_Secondary_Boys', 'Higher_Secondary_Girls',
#        'Higher_Secondary_Total', 'Metric_Type'],
#       dtype='object')

# %%
# Concatenate all datasets into a single DataFrame
combined_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
combined_df.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total',
#        'Metric_Type', 'Year', 'Upper_Primary_Boys', 'Upper_Primary_Girls',
#        'Upper_Primary_Total', 'Secondary_Boys', 'Secondary_Girls',
#        'Secondary_Total', 'Higher_Secondary_Boys', 'Higher_Secondary_Girls',
#        'Higher_Secondary_Total', 'Primary_Only', 'Primary_with_U_Primary',
#        'Primary_with_U_Primary_Sec_HrSec', 'U_Primary_Only',
#        'U_Primary_With_Sec_HrSec', 'Primary_with_U_Primary_Sec',
#        'U_Primary_With_Sec', 'Sec_Only', 'Sec_with_HrSec.', 'HrSec_Only',
#        'All Schools', 'State/UT'],
#       dtype='object')

# %%
combined_df.sample(4)
# Out:
#              State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 159  Himachal Pradesh      NaN        97.97         99.73          98.8
# 304         Rajasthan  2013-14          NaN           NaN           NaN
# 275       Lakshadweep  2014-15          NaN           NaN           NaN
# 511               NaN      NaN          NaN           NaN           NaN
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 159                NaN                 NaN                 NaN
# 304                NaN                 NaN                 NaN
# 275                NaN                 NaN                 NaN
# 511                NaN                 NaN                 NaN
#
#     Secondary _Boys Secondary _Girls  ... Primary_with_U_Primary_Sec_HrSec  \
# 159             NaN              NaN  ...                              NaN
# 304             NaN              NaN  ...                            70.33
# ...

# %%
combined_df.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total',
#        'Metric_Type', 'Year', 'Upper_Primary_Boys', 'Upper_Primary_Girls',
#        'Upper_Primary_Total', 'Secondary_Boys', 'Secondary_Girls',
#        'Secondary_Total', 'Higher_Secondary_Boys', 'Higher_Secondary_Girls',
#        'Higher_Secondary_Total', 'Primary_Only', 'Primary_with_U_Primary',
#        'Primary_with_U_Primary_Sec_HrSec', 'U_Primary_Only',
#        'U_Primary_With_Sec_HrSec', 'Primary_with_U_Primary_Sec',
#        'U_Primary_With_Sec', 'Sec_Only', 'Sec_with_HrSec.', 'HrSec_Only',
#        'All Schools', 'State/UT'],
#       dtype='object')

# %%
combined_df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of            State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0     A & N Islands  2012-13         0.83          0.51          0.68
# 1     A & N Islands  2013-14         1.35          1.06          1.21
# 2     A & N Islands  2014-15         0.47          0.55          0.51
# 3    Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4    Andhra Pradesh  2013-14         4.31          4.39          4.35
# ..              ...      ...          ...           ...           ...
# 545             NaN      NaN          NaN           NaN           NaN
# 546             NaN      NaN          NaN           NaN           NaN
# 547             NaN      NaN          NaN           NaN           NaN
# 548             NaN      NaN          NaN           NaN           NaN
# 549             NaN      NaN          NaN           NaN           NaN
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# ...

# %%
# Save the combined dataset to a CSV file
# combined_df.to_csv("combined_education_data.csv", index=False)

# %%
df2.columns
# Out:
# Index(['State_UT', 'Year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper_Primary_Boys', 'Upper_Primary_Girls', 'Upper_Primary_Total',
#        'Secondary_Boys', 'Secondary_Girls', 'Secondary_Total',
#        'Higher_Secondary_Boys', 'Higher_Secondary_Girls',
#        'Higher_Secondary_Total', 'Metric_Type'],
#       dtype='object')
